# %%
file_name='Classifier_202211241900.pth' # 副檔名通常以.pt或.pth儲存，建議使用.pth
import torch
device=torch.device('cuda') # 'cuda'/'cpu'，import torch
num_classes=10
train_size=50000
valid_size=10000
batch_size=1024
learning_rate=0.1
step_size=1000 # Reriod of learning rate decay
epochs=100

# %%
from torchvision import transforms,datasets
transforms=transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.1307),(0.3081))]) # 標準化每個channel為均值0.1307、標準差0.3081，import torchvision
dataset=datasets.MNIST('',train=True,download=False,transform=transforms) # ''指資料存放在程式目前的資料夾，train=True時dataset為60000筆訓練資料，其中dataset.data：[60000,28,28]，dataset.targets：[60000]，train=False時dataset為10000筆測試資料，其中dataset.data：[10000,28,28]，dataset.targets：[10000]，import torchvision
train_data,valid_data=torch.utils.data.random_split(dataset,[train_size,valid_size]) # import torch
train_loader=torch.utils.data.DataLoader(train_data,batch_size=batch_size,shuffle=True) # import torch
valid_loader=torch.utils.data.DataLoader(valid_data,batch_size=batch_size,shuffle=True) # import torch

# %%
from torch import nn
class CNN(nn.Module):
    def __init__(self):
        super(CNN,self).__init__()
        self.layer1=nn.Sequential(
            nn.Conv2d(in_channels=1,out_channels=16,kernel_size=5,stride=1,padding=2),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,stride=2),
        )
        self.layer2=nn.Sequential(
            nn.Conv2d(in_channels=16,out_channels=32,kernel_size=5,stride=1,padding=2),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,stride=2),
        )
        self.layer3=nn.Sequential(
            nn.Conv2d(in_channels=32,out_channels=64,kernel_size=5,stride=1,padding=2),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,stride=2),
        )        
        self.fc=nn.Linear(3*3*64,num_classes)

    def forward(self,x):
        x=self.layer1(x)
        x=self.layer2(x)
        x=self.layer3(x)
        x=x.view(x.size(0),-1)
        x=self.fc(x)
        return x

classifier=CNN().to(device)
criterion=nn.CrossEntropyLoss() # 分類
optimizer=torch.optim.Adadelta(classifier.parameters(),lr=learning_rate) # import torch
#optimizer=torch.optim.SGD(classifier.parameters(),lr=learning_rate) # import torch
scheduler=torch.optim.lr_scheduler.StepLR(optimizer,step_size,0.1) # import torch

# %%
import numpy 
train_acc_his,train_losses_his,valid_acc_his,valid_losses_his=[],[],[],[]
for i in range(1,epochs+1):
    print('Running Epoch:'+str(i))
    train_correct,train_loss,train_total,valid_correct,valid_loss,valid_total=0,0,0,0,0,0
    classifier.train()
    for img,cls in train_loader: # 一個batch的img、cls。img：[batch_size,1,28,28]，cls：[batch_size]
        img,cls=img.to(device),cls.to(device)
        pred=classifier(img) # pred：[batch_size,num_classes]
        loss=criterion(pred,cls) # loss.item()：一個batch的平均loss，[1]
        output_id=torch.max(pred,dim=1)[1] # output_id：網路輸出編號(0表示預測為第一個輸出)，[batch_size]
        train_correct+=numpy.sum(torch.eq(cls,output_id).cpu().numpy()) # 累加計算每一epoch正確預測總數，import numpy
        train_loss+=loss.item()*img.size(0) # 累加計算每一epoch的loss總和。loss.item()：一個batch的平均loss，[1]。img.size(0)：一個batch的訓練資料總數
        train_total+=img.size(0) # 累加計算訓練資料總數
        optimizer.zero_grad() # 權重梯度歸零
        loss.backward() # 計算每個權重的loss梯度
        optimizer.step() # 權重更新
    scheduler.step()

    classifier.eval()
    for img,cls in valid_loader: # 一個batch的img、cls。img：[batch_size,1,28,28]，cls：[batch_size]
        img,cls=img.to(device),cls.to(device)
        pred=classifier(img) # pred：[batch_size,num_classes]
        loss=criterion(pred,cls) # loss.item()：一個batch的平均loss，[1]
        output_id=torch.max(pred,dim=1)[1] # output_id：網路輸出編號(0表示預測為第一個輸出)，[batch_size]
        valid_correct+=numpy.sum(torch.eq(cls,output_id).cpu().numpy()) # 累加計算每一epoch正確預測總數
        valid_loss+=loss.item()*img.size(0) # 累加計算每一epoch的loss總和。loss.item()：一個batch的平均loss，[1]。img.size(0)：一個batch的驗證資料總數
        valid_total+=img.size(0) # 累加計算驗證資料總數

    train_acc=train_correct/train_total*100 # 計算每一個epoch的平均訓練正確率(%)
    train_loss=train_loss/train_total # 計算每一個epoch的平均訓練loss
    valid_acc=valid_correct/valid_total*100 # 計算每一個epoch的平均驗證正確率(%)
    valid_loss=valid_loss/valid_total # 計算每一個epoch的平均驗證loss
    train_acc_his.append(train_acc) # 累積紀錄每一個epoch的平均訓練正確率(%)，[epochs]
    train_losses_his.append(train_loss) # 累積記錄每一個epoch的平均訓練loss，[epochs]
    valid_acc_his.append(valid_acc) # 累積紀錄每一個epoch的平均驗證正確率(%)，[epochs]
    valid_losses_his.append(valid_loss) # 累積記錄每一個epoch的平均驗證loss，[epochs]
    print('Training Loss='+str(train_loss))
    print('Training Accuracy(%)='+str(train_acc))
    print('Validation Accuracy(%)='+str(valid_acc))
# Out:
# Running Epoch:1
# Training Loss=0.8706426741409302
# Training Accuracy(%)=80.962
# Validation Accuracy(%)=93.94
# Running Epoch:2
# Training Loss=0.22571052587509155
# Training Accuracy(%)=95.504
# Validation Accuracy(%)=95.95
# Running Epoch:3
# Training Loss=0.13260504496574402
# Training Accuracy(%)=96.99
# Validation Accuracy(%)=97.46000000000001
# Running Epoch:4
# Training Loss=0.09239599944591523
# Training Accuracy(%)=97.80799999999999
# Validation Accuracy(%)=97.63
# Running Epoch:5
# Training Loss=0.07254406682252884
# Training Accuracy(%)=98.2
# Validation Accuracy(%)=97.92
# Running Epoch:6
# Training Loss=0.059348179502487185
# Training Accuracy(%)=98.52199999999999
# Validation Accuracy(%)=98.28
# Running Epoch:7
# Training Loss=0.0506449546957016
# Training Accuracy(%)=98.746
# Validation Accuracy(%)=98.37
# Running Epoch:8
# Training Loss=0.043797663551568985
# Training Accuracy(%)=98.92800000000001
# Validation Accuracy(%)=98.54
# Running Epoch:9
# Training Loss=0.038455686108469965
# Training Accuracy(%)=99.116
# Validation Accuracy(%)=98.61999999999999
# Running Epoch:10
# Training Loss=0.03420127987742424
# Training Accuracy(%)=99.194
# Validation Accuracy(%)=98.67
# Running Epoch:11
# Training Loss=0.031120032860040666
# Training Accuracy(%)=99.264
# Validation Accuracy(%)=98.77
# Running Epoch:12
# Training Loss=0.027962286196947097
# Training Accuracy(%)=99.348
# Validation Accuracy(%)=98.66
# Running Epoch:13
# Training Loss=0.025565056293010712
# Training Accuracy(%)=99.41799999999999
# Validation Accuracy(%)=98.83999999999999
# Running Epoch:14
# Training Loss=0.023862441296577455
# Training Accuracy(%)=99.476
# Validation Accuracy(%)=98.82
# Running Epoch:15
# Training Loss=0.02139962548613548
# Training Accuracy(%)=99.528
# Validation Accuracy(%)=98.88
# Running Epoch:16
# Training Loss=0.019791706632971764
# Training Accuracy(%)=99.586
# Validation Accuracy(%)=98.87
# Running Epoch:17
# Training Loss=0.018324418431520464
# Training Accuracy(%)=99.626
# Validation Accuracy(%)=98.79
# Running Epoch:18
# Training Loss=0.0169748298150301
# Training Accuracy(%)=99.666
# Validation Accuracy(%)=98.87
# Running Epoch:19
# Training Loss=0.01603538794249296
# Training Accuracy(%)=99.70400000000001
# Validation Accuracy(%)=98.96000000000001
# Running Epoch:20
# Training Loss=0.014443425197005273
# Training Accuracy(%)=99.74
# Validation Accuracy(%)=98.95
# Running Epoch:21
# Training Loss=0.01329887684583664
# Training Accuracy(%)=99.792
# Validation Accuracy(%)=98.88
# Running Epoch:22
# Training Loss=0.012705745721459388
# Training Accuracy(%)=99.81400000000001
# Validation Accuracy(%)=98.9
# Running Epoch:23
# Training Loss=0.01174343242317438
# Training Accuracy(%)=99.822
# Validation Accuracy(%)=98.77
# Running Epoch:24
# Training Loss=0.0108929815736413
# Training Accuracy(%)=99.856
# Validation Accuracy(%)=98.95
# Running Epoch:25
# Training Loss=0.010226383407413959
# Training Accuracy(%)=99.864
# Validation Accuracy(%)=98.91
# Running Epoch:26
# Training Loss=0.009687593916207552
# Training Accuracy(%)=99.888
# Validation Accuracy(%)=98.92
# Running Epoch:27
# Training Loss=0.008971836809813977
# Training Accuracy(%)=99.894
# Validation Accuracy(%)=98.92
# Running Epoch:28
# Training Loss=0.008407823938727379
# Training Accuracy(%)=99.92
# Validation Accuracy(%)=98.99
# Running Epoch:29
# Training Loss=0.007758453095555305
# Training Accuracy(%)=99.932
# Validation Accuracy(%)=98.91
# Running Epoch:30
# Training Loss=0.007495717423260212
# Training Accuracy(%)=99.934
# Validation Accuracy(%)=98.83999999999999
# Running Epoch:31
# Training Loss=0.00684552285939455
# Training Accuracy(%)=99.964
# Validation Accuracy(%)=99.00999999999999
# Running Epoch:32
# Training Loss=0.00666044363617897
# Training Accuracy(%)=99.952
# Validation Accuracy(%)=99.05000000000001
# Running Epoch:33
# Training Loss=0.006117528202086687
# Training Accuracy(%)=99.968
# Validation Accuracy(%)=99.03999999999999
# Running Epoch:34
# Training Loss=0.005793094813972712
# Training Accuracy(%)=99.978
# Validation Accuracy(%)=99.02
# Running Epoch:35
# Training Loss=0.00544364950761199
# Training Accuracy(%)=99.97399999999999
# Validation Accuracy(%)=98.92999999999999
# Running Epoch:36
# Training Loss=0.005194147161915899
# Training Accuracy(%)=99.988
# Validation Accuracy(%)=99.02
# Running Epoch:37
# Training Loss=0.005034877380877733
# Training Accuracy(%)=99.982
# Validation Accuracy(%)=99.00999999999999
# Running Epoch:38
# Training Loss=0.00472223752617836
# Training Accuracy(%)=99.988
# Validation Accuracy(%)=98.98
# Running Epoch:39
# Training Loss=0.0044471195420622825
# Training Accuracy(%)=99.988
# Validation Accuracy(%)=98.98
# Running Epoch:40
# Training Loss=0.004325555660054088
# Training Accuracy(%)=99.994
# Validation Accuracy(%)=98.95
# Running Epoch:41
# Training Loss=0.003998245553970337
# Training Accuracy(%)=99.988
# Validation Accuracy(%)=99.02
# Running Epoch:42
# Training Loss=0.003882797623127699
# Training Accuracy(%)=99.99
# Validation Accuracy(%)=99.0
# Running Epoch:43
# Training Loss=0.003691871577501297
# Training Accuracy(%)=99.992
# Validation Accuracy(%)=98.95
# Running Epoch:44
# Training Loss=0.0034642664271593094
# Training Accuracy(%)=99.994
# Validation Accuracy(%)=98.97
# Running Epoch:45
# Training Loss=0.0033984514366090296
# Training Accuracy(%)=99.994
# Validation Accuracy(%)=98.94
# Running Epoch:46
# Training Loss=0.0032231836646050213
# Training Accuracy(%)=99.994
# Validation Accuracy(%)=99.06
# Running Epoch:47
# Training Loss=0.0030719910852611064
# Training Accuracy(%)=99.996
# Validation Accuracy(%)=98.94
# Running Epoch:48
# Training Loss=0.0029654454189538956
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=98.98
# Running Epoch:49
# Training Loss=0.0028382837228477
# Training Accuracy(%)=99.996
# Validation Accuracy(%)=98.97
# Running Epoch:50
# Training Loss=0.002772805343568325
# Training Accuracy(%)=99.996
# Validation Accuracy(%)=98.94
# Running Epoch:51
# Training Loss=0.0026646303448081016
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.05000000000001
# Running Epoch:52
# Training Loss=0.0025584635900333524
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.02
# Running Epoch:53
# Training Loss=0.002469903667420149
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.11
# Running Epoch:54
# Training Loss=0.002357770038023591
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.02
# Running Epoch:55
# Training Loss=0.0022885362377762794
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.05000000000001
# Running Epoch:56
# Training Loss=0.002215548855662346
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.03999999999999
# Running Epoch:57
# Training Loss=0.0021352045460045336
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.03
# Running Epoch:58
# Training Loss=0.0020620320620760323
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=98.95
# Running Epoch:59
# Training Loss=0.0020018149027600882
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.00999999999999
# Running Epoch:60
# Training Loss=0.0019437080575153232
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.1
# Running Epoch:61
# Training Loss=0.0018768843540921808
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.05000000000001
# Running Epoch:62
# Training Loss=0.001849696673080325
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.08
# Running Epoch:63
# Training Loss=0.0017895672716200352
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.11
# Running Epoch:64
# Training Loss=0.0017197481102496385
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=98.97
# Running Epoch:65
# Training Loss=0.001677096152678132
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.06
# Running Epoch:66
# Training Loss=0.001610310916006565
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.05000000000001
# Running Epoch:67
# Training Loss=0.0015853298362344503
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.00999999999999
# Running Epoch:68
# Training Loss=0.0015450706776604056
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.15
# Running Epoch:69
# Training Loss=0.001515878322608769
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.0
# Running Epoch:70
# Training Loss=0.0014546824688464403
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.08
# Running Epoch:71
# Training Loss=0.001430203900039196
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.06
# Running Epoch:72
# Training Loss=0.0013953132162615658
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.1
# Running Epoch:73
# Training Loss=0.001350766774751246
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.09
# Running Epoch:74
# Training Loss=0.001326210867241025
# Training Accuracy(%)=99.998
# Validation Accuracy(%)=99.08
# Running Epoch:75
# Training Loss=0.001294250647649169
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.09
# Running Epoch:76
# Training Loss=0.0012675880067795516
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.07000000000001
# Running Epoch:77
# Training Loss=0.0012348709410056472
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.08
# Running Epoch:78
# Training Loss=0.0012120429749414325
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.03999999999999
# Running Epoch:79
# Training Loss=0.0011857027833908796
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.11999999999999
# Running Epoch:80
# Training Loss=0.001160902988575399
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.1
# Running Epoch:81
# Training Loss=0.0011338952003419399
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.07000000000001
# Running Epoch:82
# Training Loss=0.0011221135132014751
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.09
# Running Epoch:83
# Training Loss=0.001091714690849185
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.05000000000001
# Running Epoch:84
# Training Loss=0.0010679035123065115
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=98.97
# Running Epoch:85
# Training Loss=0.0010579362300038337
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.11999999999999
# Running Epoch:86
# Training Loss=0.001033437189925462
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.1
# Running Epoch:87
# Training Loss=0.001004591699577868
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.07000000000001
# Running Epoch:88
# Training Loss=0.0009895174323022366
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.07000000000001
# Running Epoch:89
# Training Loss=0.000968183391392231
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.03999999999999
# Running Epoch:90
# Training Loss=0.0009567810614407062
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.11999999999999
# Running Epoch:91
# Training Loss=0.0009396837779507041
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.08
# Running Epoch:92
# Training Loss=0.000923302769754082
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.02
# Running Epoch:93
# Training Loss=0.0009081887152045965
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.1
# Running Epoch:94
# Training Loss=0.0008957135593146085
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.1
# Running Epoch:95
# Training Loss=0.0008821048660762608
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.06
# Running Epoch:96
# Training Loss=0.0008677742758765816
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.07000000000001
# Running Epoch:97
# Training Loss=0.0008599680392071604
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.05000000000001
# Running Epoch:98
# Training Loss=0.0008372899533435703
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.08
# Running Epoch:99
# Training Loss=0.0008250161086954176
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.09
# Running Epoch:100
# Training Loss=0.0008108570906333626
# Training Accuracy(%)=100.0
# Validation Accuracy(%)=99.1

# %%
# 顯示第71筆訓練資料影像
import matplotlib.pyplot as plt
plt.imshow(dataset.data[70],cmap='gray') # 繪製點陣圖，cmap='gray'：灰階
plt.axis('off') # 隱藏刻度
# Out:
# (-0.5, 27.5, 27.5, -0.5)

# %%
# 對訓練過程繪圖
plt.figure(figsize=(15,10))
plt.subplot(211)
plt.plot(train_acc_his,'b',label='trainingaccuracy')
plt.plot(valid_acc_his,'r',label='validation accuracy')
plt.title('Accuracy(%)')
plt.legend(loc='best')
plt.subplot(212)
plt.plot(train_losses_his,'b',label='training loss')
plt.plot(valid_losses_his,'r',label='validation loss')
plt.title('Loss')
plt.legend(loc='best')
plt.show()

# %%
torch.save(classifier.state_dict(),file_name)
